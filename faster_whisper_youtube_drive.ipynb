# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedTaani/BankProjekt/blob/master/faster_whisper_youtube_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Youtube/Google Drive Videos Translation/Transcription with Faster Whisper**
#
# [faster-whisper](https://github.com/guillaumekln/faster-whisper) is a reimplementation of OpenAI's Whisper model using CTranslate2, which is a fast inference engine for Transformer models.
#
# This implementation is up to 4 times faster than openai/whisper for the same accuracy while using less memory. The efficiency can be further improved with 8-bit quantization on both CPU and GPU.
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription or translation of a  video file (from Youtube/Google Drive) using Faster Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the output and video audio in your Google Drive.
#
# ## **How to use**
# 1. Read and understand the notebook. You should at the very least modify the **video selection section** to choose the video you wish to translate/transcribe
# 2. Click Runtime -> Run all and wait for the notebook to do its magic, alternatively you may run the cells one by one and skip the Google Drive portion if you do not intend to use it
# 3. A download prompt should appear once subtitles is ready, or check the 'Files' tab on the left for the output

# %%
#@markdown # **[Optional]** Access data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
from pathlib import Path

drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Faster Whisper" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-6d96063c-c0e9-681f-abf8-a96375dc10a1)
# Wed Sep 17 17:24:19 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0             29W /   70W |    1670MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Faster Whisper.

#@markdown ---

! pip install faster-whisper
! pip install yt-dlp

import os
import sys
import warnings
from faster_whisper import WhisperModel
import yt_dlp
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo
import requests
from urllib.parse import urlsplit
from google.colab import files
from pathlib import Path

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)

# !sudo apt-get update
# !sudo apt install nvidia-cuda-toolkit
# Out:
# Requirement already satisfied: faster-whisper in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (4.6.0)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.34.4)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.22.0)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (1.22.1)
# Requirement already satisfied: av>=11 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (15.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (4.67.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.0.2)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.13->faster-whisper) (1.1.9)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.13.3)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper) (10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.12/dist-packages (2025.9.5)
# Using device: cuda:0
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# nvidia-cuda-toolkit is already the newest version (11.5.1-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
#@markdown # **Model selection** 🧠

#@markdown There are several models to choose from, with varying performance and speed. large-v2 is recommended for most cases:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~0.8 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1.0 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~1.4 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~2.7 GB     |      ~2x       |
#@markdown | large-v1  |   1550 M   |        N/A         |      `large-v1`       |    ~4.3 GB     |       1x       |
#@markdown | large-v2  |   1550 M   |        N/A         |      `large-v2`       |    ~4.3 GB     |       1x       |

#@markdown ---
model_size = 'medium' #@param ['tiny', 'tiny.en', 'base', 'base.en', 'small', 'small.en', 'medium', 'medium.en', 'large-v1', 'large-v2']
device_type = "cuda" #@param {type:"string"} ['cuda', 'cpu']
compute_type = "float16" #@param {type:"string"} ['float16', 'int8_float16', 'int8']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

model = WhisperModel(model_size, device=device_type, compute_type=compute_type)

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video **OR** Google drive video path of the video you want to translate/transcribe, and run the cell. Make sure the correct Type is chosen! This may take awhile depending on video file size.

Type = "Google Drive" #@param ['Youtube video or playlist', 'Google Drive', 'Direct download']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "https://www.youtube.com/watch?v=9ez8lm9I26Y" #@param {type:"string"}
# store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "Colab Notebooks/gg.mp3" #@param {type:"string"}
#@markdown ---
#@markdown #### **Direct Download**
ddl_url = "https://www.example.com/video.mkv" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":

    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        # ℹ️ See help(yt_dlp.postprocessor) for a list of available Postprocessors and their arguments
        'postprocessors': [{  # Extract audio using ffmpeg
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([URL])
        list_video_info = [ydl.extract_info(URL, download=False)]

    for video_info in list_video_info:
        video_path_local_list.append(Path(f"{video_info['id']}.wav"))

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for processing.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        print(f"{video_path_local} appended to list for processing")
        display(Markdown(f"**{str(video_path)} selected for processing.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

elif Type == "Direct download":
    print(f"⚠️ Please ensure this is a direct download link and is of a valid format")
    print(f"Attempting to download: {ddl_url}\n")
    # !wget {ddl_url} -O ddl_video.mp4
    # video_path_local_list.append("/content/ddl_video.mp4")

    response = requests.get(ddl_url)

    if response.status_code == 200:
        # Extract the filename from the URL
        filename = urlsplit(ddl_url).path.split("/")[-1]

        # Create the full path for the destination file in the current working directory
        destination_path = os.path.join(os.getcwd(), filename)

        # Save the file
        with open(destination_path, 'wb') as file:
            file.write(response.content)

        print(f"File downloaded successfully: {destination_path}")

        video_path_local = Path(".").resolve() / (filename)

        # print(f"Path local: {video_path_local}") # /content/video.mkv

        video_path_local_list.append(video_path_local)
    else:
        print(f"Failed to download file. Status code: {response.status_code}")

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    valid_suffixes = [".mp4", ".mkv", ".mov", ".avi", ".wmv", ".flv", ".webm", ".3gp", ".mpeg"]

    print(f"Processing video file {video_path_local} with ffmpeg..")

    if video_path_local.suffix in valid_suffixes:
        input_suffix = video_path_local.suffix
        video_path_local = video_path_local.with_suffix(".wav")
        result = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(input_suffix)), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# /content/gg.mp3 appended to list for processing
# **/content/drive/My Drive/Colab Notebooks/gg.mp3 selected for processing.**
# Processing video file /content/gg.mp3 with ffmpeg..

# %%
def seconds_to_time_format(s):
    # Convert seconds to hours, minutes, seconds, and milliseconds
    hours = s // 3600
    s %= 3600
    minutes = s // 60
    s %= 60
    seconds = s // 1
    milliseconds = round((s % 1) * 1000)

    # Return the formatted string
    return f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d},{int(milliseconds):03d}"

#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription/translation of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown #### Language
language = "de" #@param ["auto", "en", "zh", "ja", "fr", "de"] {allow-input: true}
#@markdown #### initial prompt (change to transcribe if you prefer transcribing only)
initial_prompt = "transcribe" #@param {type:"string"}
#@markdown ---
#@markdown #### Word-level timestamps
word_level_timestamps = False #@param {type:"boolean"}
#@markdown ---
#@markdown #### VAD filter
vad_filter = True #@param {type:"boolean"}
vad_filter_min_silence_duration_ms = 50 #@param {type:"integer"}
#@markdown ---
#@markdown #### Output (Default is srt, txt if `text_only` be checked )
text_only = True #@param {type:"boolean"}


segments, info = model.transcribe(str(video_path_local), beam_size=5,
                                  language=None if language == "auto" else language,
                                  initial_prompt=initial_prompt,
                                  word_timestamps=word_level_timestamps,
                                  vad_filter=vad_filter,
                                  vad_parameters=dict(min_silence_duration_ms=vad_filter_min_silence_duration_ms))

display(Markdown(f"Detected language '{info.language}' with probability {info.language_probability}"))

ext_name = '.txt' if text_only else ".srt"
output_file_name = video_path_local.stem + ext_name
sentence_idx = 1
with open(output_file_name, 'w') as f:
  for segment in segments:
    if word_level_timestamps:
      for word in segment.words:
        ts_start = seconds_to_time_format(word.start)
        ts_end = seconds_to_time_format(word.end)
        print(f"[{ts_start} --> {ts_end}] {word.word}")
        if not text_only:
          f.write(f"{sentence_idx}\n")
          f.write(f"{ts_start} --> {ts_end}\n")
          f.write(f"{word.word}\n\n")
        else:
          f.write(f"{word.word}")
        f.write("\n")
        sentence_idx = sentence_idx + 1
    else:
      ts_start = seconds_to_time_format(segment.start)
      ts_end = seconds_to_time_format(segment.end)
      print(f"[{ts_start} --> {ts_end}] {segment.text}")
      if not text_only:
        f.write(f"{sentence_idx}\n")
        f.write(f"{ts_start} --> {ts_end}\n")
        f.write(f"{segment.text.strip()}\n\n")
      else:
        f.write(f"{segment.text.strip()}\n")
      sentence_idx = sentence_idx + 1

try:
  files.download(output_file_name)
  shutil.copy(video_path_local.parent / output_file_name,
            drive_whisper_path / output_file_name
  )
  display(Markdown(f"**Output file created: {drive_whisper_path / output_file_name}**"))
except:
  display(Markdown(f"**Output file created: {video_path_local.parent / output_file_name}**"))
# Out:
# Detected language 'de' with probability 1
# [00:00:07,150 --> 00:00:12,650]  Ja, hallo, guten Tag zusammen. Herzlich willkommen zur Vorlesung
# [00:00:12,650 --> 00:00:18,370]  Theoretische Grundlagen der Informatik. Wie Sie sehen, fange ich pünktlich an.
# [00:00:18,370 --> 00:00:22,300]  Sie sollten also auch in Zukunft pünktlich kommen, dann können wir auch
# [00:00:22,300 --> 00:00:28,720]  pünktlich die Vorlesung beenden um 13 Uhr, damit Sie noch in die Mensa kommen.
# [00:00:28,720 --> 00:00:41,250]  Also, die Semestervorlesung Theoretische Grundlagen der Informatik,
# [00:00:41,570 --> 00:00:47,330]  Pflichtvorlesung im Informatik-Bachelorstudiengang, drittes Semester und
# [00:00:47,330 --> 00:00:51,570]  ich weiß, es sind auch Informationswörter, vielleicht auch Mathematiker unter Ihnen.
# [00:00:51,570 --> 00:00:56,570]  Ich werde jetzt am Anfang erstmal ein paar organisatorische Dinge sagen, ja.
# [00:00:56,570 --> 00:01:05,920]  Also wer wir sind, wer ich bin, wer die Mitarbeiter sind, Mitarbeiterinnen, die
# [00:01:05,920 --> 00:01:13,060]  die Übungen halten, wie das mit den Übungen oder Tutorien ist, wo sie die
# [00:10:31,660 --> 00:10:36,500]  etwas öfter. Und dann sind die Termine so getaktet, dass es thematisch passt und
# [00:10:36,500 --> 00:10:40,660]  teilweise auch zu meinen Verpflichtungen außerhalb passt. Also es gibt ein paar
# [00:10:40,660 --> 00:10:45,380]  einzelne Tage, Donnerstage oder Dienstage im Semester, wo ich dringend
# [00:10:45,420 --> 00:10:49,180]  irgendwo anders sein muss. Und ich habe das sozusagen so durchgetaktet, dass
# [00:10:49,180 --> 00:10:53,620]  ich mich nicht vertreten lassen muss oder die Vorlesung ausfallen muss,
# [00:10:53,620 --> 00:10:59,380]  sondern dass es halt genau hinkommt mit den Übungen. Das heißt also, da das eben
# [00:10:59,380 --> 00:11:05,500]  nicht so 100 Prozent jede zweite Woche eine Übung ist, ist das also nur etwa
# [00:11:05,500 --> 00:11:11,380]  jeden zweiten Dienstag das neues Blatt rausgegeben wird. Und entsprechend haben
# [00:11:11,420 --> 00:11:15,580]  Sie zur Bearbeitungszeit ein bis zwei Wochen, also manchmal ist es etwas kürzer.
# [00:11:16,060 --> 00:11:21,220]  Das Abgabedatum, also die Deadline steht aber jeweils auf dem aktuellen Übungsblatt,
# [00:11:21,300 --> 00:11:27,620]  sollten Sie beachten. Und dann können Sie also Ihre bearbeiteten Übungen abgeben
# [00:11:28,220 --> 00:11:32,540]  in so einem Kasten im Untergeschoss des Informatikgebäudes. Ich bin mir sicher,
# [00:11:32,540 --> 00:11:40,100]  Sie wissen besser als ich, wo dieser Kasten steht. Die Übungen, die von Ihnen
# [00:11:40,100 --> 00:11:47,620]  bearbeiteten Übungen werden korrigiert von den Tutorinnen und die korrigierten
# [00:11:47,620 --> 00:11:50,940]  Blätter bekommen Sie dann in dem entsprechenden Tutorium, in dem Sie sich
# [00:11:51,260 --> 00:12:00,000]  angemeldet haben. Kommen Sie dann wieder zurück. Die Lösungen werden in den
# [00:12:00,000 --> 00:12:07,900]  Plenarübungen besprochen und das erste Übungsblatt gibt es heute. Heute geht
# [00:12:07,900 --> 00:12:14,580]  schon los. Und jetzt zur Bearbeitung der Übungen. Ich kann Ihnen nur wärmstens
# [00:12:14,580 --> 00:12:21,900]  empfehlen, die Übungen zu bearbeiten. Das müssen Sie nicht machen, aber die
# [00:12:21,900 --> 00:12:26,220]  Erfahrung lehrt, dass diejenigen, die das machen, insgesamt auch einen größeren
# [00:12:26,220 --> 00:12:33,460]  Erfolg haben. Da gibt es ganz tolle Statistiken zu. Sie dürfen, und ich
# [00:12:33,500 --> 00:12:39,640]  empfehle das sogar, zu zweit zusammenarbeiten. Also können zwei zusammen
# [00:12:39,640 --> 00:12:46,520]  sozusagen die Übungen bearbeiten und einen Lösungsblatt abgeben.
# [00:12:47,080 --> 00:12:52,240]  Allerdings bitte nur, wenn beide im selben Tutorium sind. Das wird sonst
# [00:12:52,240 --> 00:12:59,800]  einfach logistisch zu schwierig. Und bitte schreiben Sie auf Ihre Übung auch
# [00:12:59,800 --> 00:13:06,200]  alle relevanten Informationen, wie Name, Vorname, Matrikelnummer, Tutoriumsnummer,
# [00:13:06,200 --> 00:13:11,830]  Nummer des Tutors. Sonst ist es einfach schwierig, in der einen oder anderen
# [00:13:11,830 --> 00:13:17,070]  Weise Ihre Übungen zuzuordnen. Und bitte keine lose Plättersammlung, sondern
# [00:13:17,070 --> 00:13:23,020]  zusammenheften. So, jetzt ein Punkt. Ich hoffe, Sie können noch mit der Hand
# [00:13:23,020 --> 00:13:29,580]  schreiben. Also die Übungsblätter müssen handschriftlich, also die Lösungen,
# [00:13:29,740 --> 00:13:34,620]  Ihre Hausaufgaben handschriftlich abgegeben werden. Das machen wir einfach
# [00:13:34,620 --> 00:13:42,860]  um Duplizieren von Lösungen, sozusagen abschreiben, um das in einer gewissen
# [00:13:42,860 --> 00:13:47,340]  Weise zu unterbinden. Ich weiß, man kann auch mit der Hand abschreiben, aber ja,
# [00:13:47,340 --> 00:13:53,900]  das ist halt eher eine heuristische Art und Weise, um sozusagen Kopieren zu
# [00:13:54,380 --> 00:14:00,220]  unterbinden. Das heißt also eine Kopie von irgendwas oder was ausgedrucktes
# [00:14:00,260 --> 00:14:06,750]  bitte nicht abgeben. Und wenn Sie abschreiben, nicht Ihre eigenen Lösungen
# [00:14:06,750 --> 00:14:15,330]  abgeben, sondern von anderen Kopierte, dann gibt es halt keine Punkte. So, wozu
# [00:14:15,330 --> 00:14:22,250]  das Ganze? Ja, natürlich, damit Sie den Stoff besser lernen. Also ein intrinsisches
# [00:14:22,570 --> 00:14:27,390]  Interesse sollten Sie haben, diese Übungen zu machen. Sie kriegen aber auch
# [00:14:27,430 --> 00:14:35,350]  einen kleinen Bonus, wenn Sie mindestens 50 Prozent der Punkte, die Sie über die
# [00:14:35,350 --> 00:14:41,150]  Übungen bekommen könnten, auch bekommen. Dann kriegen Sie einen kleinen Klausurbonus.
# [00:14:41,750 --> 00:14:46,030]  Der zählt allerdings nur, wenn Sie die Klausur so wie sie gestellt ist, mindestens
# [00:14:46,030 --> 00:14:49,590]  bestehen. Also Sie können Ihre Note sozusagen ein kleines bisschen aufbessern
# [00:14:50,190 --> 00:14:56,710]  darüber. Das sage ich ja, weil oder das machen wir so, weil wir aus Erfahrung
# [00:14:56,750 --> 00:15:01,910]  wissen, dass der Mensch manchmal zusätzliche Motivation braucht, um was
# [00:15:01,910 --> 00:15:08,850]  zu machen, was eigentlich für sich genommen schon sinnvoll ist. Okay, zum
# [00:15:08,850 --> 00:15:13,330]  Tutorien, also da werden die Übungsblätter zurückgegeben und da wird
# [00:15:13,330 --> 00:15:17,930]  eben zusätzlicher Stoff behandelt, also nicht zusätzlicher Stoff, das ist jetzt
# [00:15:17,930 --> 00:15:22,770]  falsch ausgedrückt. Da werden sozusagen zusätzlich geübt, also zusätzliche
# [00:15:22,770 --> 00:15:29,770]  Aufgaben und Beispiele zur Vorlesung behandelt. Los geht es ab nächster Woche.
# [00:15:30,800 --> 00:15:35,680]  Und Sie müssen sich natürlich eintragen in Tutorien. Das geht über
# [00:18:16,390 --> 00:18:20,630]  Klausur über theoretische Grundlagen der Informatik eine Dauer von zwei Stunden
# [00:18:20,630 --> 00:18:25,030]  hat. Es gab natürlich eine Vorgängerveranstaltung, die hieß
# [00:18:25,150 --> 00:18:31,390]  Informatik 3, war genauso im dritten Semester, damals im Diplomstudiengang. Die
# [00:18:31,390 --> 00:18:35,270]  dauerte aber aus irgendwelchen Gründen, die ich nie verstanden habe, nur eine
# [00:18:35,270 --> 00:18:39,750]  Stunde. Das ist deshalb relevant, weil es alte Klausuren gibt und die alten
# [00:18:39,750 --> 00:18:43,350]  Klausuren, die also noch aus der Zeit sind, die können Sie natürlich auch als
# [00:18:43,350 --> 00:18:47,390]  Übungsmaterial verwenden, aber da sollten Sie beachten, dass die damals für eine
# [00:18:47,390 --> 00:18:51,950]  Stunde konzipiert waren, während jetzt die neueren Klausuren, also seit es den
# [00:18:51,990 --> 00:18:56,750]  Bachelor-Studiengang gibt, eben für zwei Stunden konzipiert sind. Also Sie können
# [00:18:56,750 --> 00:19:01,660]  sich auf den alten Klausuren auf der Homepage an denen austoben auch, wenn Sie
# [00:19:01,660 --> 00:19:07,420]  sich auf die Klausur vorbereiten. Im Stil bleiben die gleich. Und da meine ich
# [00:19:07,420 --> 00:19:15,860]  jetzt vor allem die Klausuren zur Vorlesung TGI in den Semestern, in denen ich
# [00:19:15,860 --> 00:19:19,340]  die Veranstaltung gehalten habe. Das heißt nicht, dass die anderen, also in
# [00:19:19,340 --> 00:19:24,740]  der Zwischenzeit hat zum Beispiel Herr Müller-Quade die Vorlesung gehalten. Das
# [00:19:24,740 --> 00:19:27,100]  heißt nicht, dass die jetzt irrelevant sind, aber er hat einfach ein bisschen
# [00:19:27,100 --> 00:19:30,220]  anderen Stil. Also die Klausuren sehen einfach ein bisschen anders aus.
# [00:19:30,220 --> 00:19:36,500]  Also aber hier, das was es da gibt aus dem Wintersemester 10.11 und 11.12 ist
# [00:19:36,500 --> 00:19:40,420]  hochrelevant für Sie und brauchbar. Und dann gibt es, wie gesagt, diese
# [00:19:40,420 --> 00:19:45,940]  Informatik 3 Klausuren aus vorherigen Zeiten, aber die sind für eine Stunde
# [00:19:45,940 --> 00:19:55,110]  konzipiert gewesen. Nochmal Sie können also, wenn Sie die Hausaufgaben machen und 50
# [00:19:55,110 --> 00:20:01,030]  Prozent der erreichbaren Punkte erreichen, einen kleinen Klausurbonus erzielen, der
# [00:20:01,030 --> 00:20:06,030]  auf bestandene Klausuren angerechnet wird. So und das was hier steht,
# [00:20:06,030 --> 00:20:09,670]  habe ich schon gesagt. Die zweite Klausur ist irgendwann, ich weiß nicht,
# [00:20:09,670 --> 00:20:13,790]  September, August, September, Oktober in der Größenordnung. Der Termin steht
# [00:20:13,790 --> 00:20:18,950]  aber noch nicht fest. Da habe ich jetzt auch keinen Einfluss drauf, wann der
# [00:20:18,950 --> 00:20:22,310]  festgelegt wird. Ich denke aber noch während der Vorlesungszeit wird der
# [00:20:22,310 --> 00:20:27,540]  festgelegt. Aber Sie sollten planen im Februar mitzuschreiben, dann hätten Sie
# [00:22:58,740 --> 00:23:03,420]  Berechenbarkeit und auch bei der Komplexitätstheorie und im zweiten bei
# [00:23:03,500 --> 00:23:09,430]  der Komplexitätstheorie ist das vielleicht sogar noch merkwürdiger uns
# [00:23:09,430 --> 00:23:16,600]  immer, wenn wir so formale Beweise führen, auf eine Sprachenebene begeben.
# [00:23:16,600 --> 00:23:20,120]  Also was wir, selbst wenn wir im Kopf haben, wir wollen wissen, ob ein
# [00:23:20,120 --> 00:23:26,560]  bestimmtes Problem berechenbar ist oder effizient gelöst werden kann oder eben
# [00:23:26,560 --> 00:23:32,130]  zu den schweren Problemen gehört, was auch immer schwer heißt, werden wir das
# [00:23:32,170 --> 00:23:36,210]  nicht auf Problem-Ebene, sondern auf Sprach-Ebene machen. Also das Akzeptieren
# [00:23:36,210 --> 00:23:42,210]  einer Sprache gibt es ein Computer oder ein Rechenmodell, das eine bestimmte
# [00:23:42,210 --> 00:23:48,000]  Sprache akzeptieren kann. Das ist, wie gesagt, ein bisschen merkwürdig, vor
# [00:23:48,000 --> 00:23:51,560]  allem, wenn man eigentlich bei der Komplexitätstheorie das Lösen von
# [00:23:51,560 --> 00:23:57,960]  Problemen im Kopf hat und vor allem eben, was hat das für Konsequenzen für die
# [00:23:57,960 --> 00:24:05,180]  Existenz von Algorithmen einer bestimmten Art, aber wir führen das
# [00:24:05,180 --> 00:24:10,740]  sozusagen auf diese Sprach-Ebene zurück, weil man dann eine wirklich durchgehende
# [00:24:10,740 --> 00:24:19,700]  Kette hat von fundierten Argumenten, so wie bei einem mathematischen Beweis. Und
# [00:24:19,700 --> 00:24:25,230]  dazu braucht man dann natürlich auch ein Modell eines Computers. So, das heißt
# [00:24:25,270 --> 00:24:32,700]  also ein Thema der Veranstaltung ist, einfache, abstrakte Modelle von
# [00:24:32,700 --> 00:24:41,110]  Berechnung zu betrachten und danach zu beurteilen, was mit dem, wie mächtig
# [00:24:41,110 --> 00:24:46,580]  dieses Modell ist. Das klingt sehr abstrakt und sieht auch teilweise so sehr
# [00:24:46,580 --> 00:24:51,540]  theoretisch und abgefahren aus, also im Sinne von hat nichts mit der Realität
# [00:24:51,660 --> 00:24:56,260]  zu tun. Das hat aber deutlich mehr mit der Realität zu tun, als man vielleicht
# [00:24:56,260 --> 00:25:01,990]  im ersten Moment denken mag, denn man kann man kann das, was ein real
# [00:25:01,990 --> 00:25:06,270]  existierender Computer kann oder nicht kann, tatsächlich auf eine abstrakte
# [00:25:06,270 --> 00:25:12,990]  Ebene heben, wo die Abstraktion sehr einfach aussieht, sehr einfach zu
# [00:25:12,990 --> 00:25:17,540]  beschreiben ist. Und das werden wir hier in der Vorlesung machen. Und damit eng
# [00:25:17,540 --> 00:25:29,700]  verknüpft ist, wie ausdrucksfähig sind bestimmte Sprachen, also welches
# [00:25:29,700 --> 00:25:35,300]  Rechnermodell kann welche Sprachen erkennen, akzeptieren, das habe ich eben
# [00:25:35,300 --> 00:25:40,380]  schon gesagt. Also Sprachen akzeptieren ist das, worüber wir reden, wenn wir
# [00:25:40,380 --> 00:25:44,300]  immer sozusagen wirklich fundierte Beweise führen, selbst wenn wir
# [00:25:44,300 --> 00:25:49,220]  eigentlich an Lösbarkeit von Problemen interessiert sind. Und dann muss man
# [00:25:49,220 --> 00:25:53,020]  natürlich auch ein Augenmerk haben auf der Sprache, die man benutzt, um
# [00:25:53,020 --> 00:25:55,980]  irgendwas auszudrücken, um es zu formulieren.
# [00:25:55,980 --> 00:26:00,810]  Das sind also so grundlegende Fragen, die in der Vorlesung behandelt werden.
# [00:26:00,810 --> 00:26:06,620]  Das heißt also Ziel der Vorlesung ist einen vertieften Einblick in die
# [00:26:06,620 --> 00:26:13,740]  Grundlagen der theoretischen Informatik zu geben. Und was sie also dann am Schluss
# [00:26:13,740 --> 00:26:19,060]  mitnehmen sollten, ist natürlich dieses Wissen über Berechenbarkeit und
# [00:26:19,060 --> 00:26:27,200]  Nichtberechenbarkeit, das Wissen über gewisse Komplexitätsklassen, das Wissen
# [00:26:27,200 --> 00:26:34,420]  über einfache Berechnungsmodelle, die dazugehören und deren Mächtigkeit, da
# [00:26:34,420 --> 00:26:40,980]  gibt es Modelle, die sind weniger mächtig, mächtigere Modelle, kennen auch die
# [00:26:40,980 --> 00:26:50,220]  grundlegenden, endliche Automaten einerseits, Touring-Maschine. Und natürlich
# [00:26:50,300 --> 00:26:57,260]  ein Verständnis sozusagen für die Grenzen dessen, was möglich ist. Also ein Großteil
# [00:26:57,260 --> 00:27:02,460]  der Ergebnisse, die wir hier beweisen werden, sind also Ergebnisse, die sozusagen
# [00:27:02,460 --> 00:27:08,300]  die Grenzen aufzeichnen, das, was nicht mehr geht, was nicht berechenbar ist, was
# [00:27:08,300 --> 00:27:14,100]  zu komplex ist, um in einer bestimmten Art und Weise gelöst werden können. Sie
# [00:27:14,180 --> 00:27:20,850]  brauchen dafür ein bestimmtes Abstraktionsvermögen, solche grundlegenden
# [00:27:20,850 --> 00:27:29,300]  Aspekte wie eben Modelle für Berechnung oder Konzepte von Programmiersprachen zu
# [00:27:29,300 --> 00:27:37,060]  verstehen. Und sie sollten auch gewisse Techniken lernen. Also spätestens bei der
# [00:27:37,060 --> 00:27:41,140]  Evaluation der Vorlesung höre ich oft von denjenigen, die die Vorlesung halt
# [00:27:41,140 --> 00:27:48,650]  nicht mögen, es gibt es, da sind zu viele Beweise drin. TGI finde ich nicht gut,
# [00:27:48,650 --> 00:27:56,730]  da sind zu viele Beweise drin. Das ist eine essentielle Eigenschaft dieses
# [00:27:56,730 --> 00:28:02,650]  Themas und dieser Vorlesung, dass Beweise geführt werden. Dieses Wissen, ein
# [00:28:02,650 --> 00:28:07,570]  bestimmtes Problem ist nicht berechenbar oder ein bestimmtes Problem ist NP-vollständig
# [00:28:07,610 --> 00:28:15,730]  und damit sehr komplex. Dieses Wissen, das ist wenig wert. Sie müssen die Konzepte,
# [00:28:15,730 --> 00:28:21,370]  die dahinterstehen, verstehen und sie sollten auch die ganz grundlegenden
# [00:28:21,370 --> 00:28:25,250]  Techniken, die man braucht, um solche Aussagen zu treffen, wie ein bestimmtes
# [00:28:25,250 --> 00:28:29,010]  Problem ist nicht berechenbar, ein bestimmtes Problem ist NP-vollständig,
# [00:28:29,570 --> 00:28:36,940]  diese Techniken sollten sie auch kennen. Was sind so Techniken, wie wenn man eben
# [00:28:36,940 --> 00:28:40,940]  weiß, ein bestimmtes Problem ist nicht berechenbar und jetzt ein anderes
# [00:28:40,940 --> 00:28:45,900]  betrachtet, von dem man das Gefühl hat, das ist irgendwie genauso nicht berechenbar
# [00:28:45,900 --> 00:28:50,460]  wie dieses erste, wie sie dies auch beweisen können, mit Hilfe der Kenntnis,
# [00:28:50,460 --> 00:28:55,780]  dass dieses erste nicht berechenbar ist. Das ist ein ganz berühmtes Konzept der
# [00:28:55,780 --> 00:29:02,180]  theoretischen Informatik, die Reduktion auf ein anderes Problem. Bei Komplexitätsaussagen
# [00:29:02,180 --> 00:29:05,340]  geht das genauso. Sie haben da ein Problem, von dem wissen Sie das sehr
# [00:29:05,340 --> 00:29:12,010]  schwer. Jetzt betrachten Sie ein neues Problem, sag ich mal, für Sie neu und Sie
# [00:29:12,010 --> 00:29:16,250]  wissen nicht, ist das jetzt leichter als das andere oder schwerer als das andere
# [00:29:16,250 --> 00:29:21,930]  oder mindestens genauso schwer wie das andere und um zu zeigen, dass es mindestens
# [00:29:21,930 --> 00:29:27,330]  genauso schwer wie das andere ist und das ist der gängige Weg, um Probleme in
# [00:29:27,330 --> 00:29:33,250]  gewisse Komplexitätsklassen einzuteilen, brauchen Sie eine Technik, die nennt sich
# [00:29:33,250 --> 00:29:37,410]  wiederum Reduktion. Sie reduzieren das Problem auf das vorherige, von dem Sie
# [00:29:37,410 --> 00:29:42,850]  wissen, wie schwierig es ist. Also diese Konzepte, die müssen Sie am Schluss auch
# [00:29:42,850 --> 00:29:48,720]  beherrschen und das muss dann auch in der Klausur angewendet werden.
# [00:29:48,720 --> 00:29:57,780]  Okay, so, ich habe eben schon gesagt, zu zwei anderen Veranstaltungen gibt es vor
# [00:29:57,780 --> 00:30:02,900]  allem Querbezüge. Einerseits zu Algorithmen 1, das betrifft vor allem
# [00:30:02,900 --> 00:30:09,950]  Komplexität von Problemen, weil man halt daran interessiert ist, effiziente
# [00:30:09,950 --> 00:30:12,830]  Algorithmen zur Lösung von Problemen zu entwerfen, das macht man in der
# [00:30:12,830 --> 00:30:19,270]  Algorithmen 1 Vorlesung und in Algorithmen 2 im fünften Semester und eben als
# [00:30:19,270 --> 00:30:24,790]  Grundlage für vieles, was da gemacht wird, zumindest Hintergrund, ist dann diese
# [00:30:24,790 --> 00:30:30,230]  Veranstaltung TGI und da vor allem das Kapitel Komplexitätsklassen relevant und
# [00:30:30,230 --> 00:30:35,560]  andererseits gibt es Bezüge zu Grundbegriffe der Informatik, GBI, und
# [00:30:35,560 --> 00:30:42,920]  heute, wenn Sie den Rest der Vorlesung, Begriffe wiederholen, die Sie dort schon
# [00:32:48,940 --> 00:32:54,220]  Und bei den endlichen Automaten, insbesondere der Aspekt Determinismus versus
# [00:32:54,260 --> 00:32:59,980]  Nicht-Determinismus, so diese Worte, endliche Automaten, reguläre Sprachen,
# [00:32:59,980 --> 00:33:04,700]  deterministisch, nicht-deterministisch, die haben Sie in GBI schon gehört.
# [00:33:04,700 --> 00:33:11,300]  Aber spätestens bei dem sozusagen Abhandeln von Determinismus versus
# [00:33:11,300 --> 00:33:15,340]  Nicht-Determinismus im Zusammenhang mit endlichen Automaten werden Sie sehr schnell
# [00:33:15,340 --> 00:33:18,740]  sehen, dass was wir hier wirklich fundiert machen, wäre, dass in GBI nicht
# [00:33:18,740 --> 00:33:24,700]  weiter gemacht wurde. So, damit hier diese Veranstaltung jetzt aber in sich
# [00:33:24,700 --> 00:33:28,420]  abgeschlossen ist, also jetzt erstmal ein paar Begriffe zur Wiederholung, die Sie
# [00:33:28,420 --> 00:33:31,700]  schon kennen, aber es schadet ja auch nicht, wenn Sie sich jetzt vor Augen führen,
# [00:33:31,700 --> 00:33:34,980]  denn ab Donnerstag wird damit dann weiter gearbeitet.
# [00:33:34,980 --> 00:33:39,940]  So und die ersten Begriffe sind die Begriffe eines Wortes oder Wörter,
# [00:33:39,940 --> 00:33:43,740]  formale Sprachen, reguläre Ausdrücke, endliche Automaten und kontextfreie
# [00:33:43,740 --> 00:33:47,900]  Grammatiken. Also alles Themen, die in GBI mal kurz dran waren.
# [00:33:47,980 --> 00:33:51,820]  Und hier als Wiederholung noch mal kommen, damit wir dann am Donnerstag darauf
# [00:33:51,820 --> 00:34:02,910]  weiter aufbauen können. So, also Wörter. Sie betrachten ein Alphabet Sigma und
# [00:34:02,910 --> 00:34:08,350]  zwar ist es definiert als eine endliche Menge von Zeichen. Beispiel Sigma besteht
# [00:34:08,350 --> 00:34:12,310]  nur aus den Zeichen 0 und 1. Bei vielen Beispielen, die wir hier betrachten,
# [00:34:12,310 --> 00:34:16,950]  kommen wir mit diesem kleinen Alphabet aus, aber das Alphabet könnte natürlich
# [00:34:16,950 --> 00:34:23,950]  auch deutlich mehr Zeichen enthalten. So und dann ist ein Wort W über einem
# [00:34:23,950 --> 00:34:30,670]  vorgegebenen Alphabet Sigma einfach eine Folge von Zeichen aus Sigma.
# [00:34:30,670 --> 00:34:36,990]  Diese Folge kann auch Länge 0 haben, also leer sein.
# [00:34:36,990 --> 00:34:45,530]  Das heißt also, das leere Wort, diese Länge von Zeichen der Länge, Folge von
# [00:34:45,530 --> 00:34:52,140]  Zeichen der Länge 0 ist ein Wort. Einfaches Beispiel, etwa so eine
# [00:34:52,140 --> 00:34:58,740]  Zeichenkette 001 001 0, das ist ein Wort über dem Alphabet Sigma gleich 01.
# [00:34:58,740 --> 00:35:07,320]  Das leere Wort, also Wort über Sigma der Länge 0, das symbolisieren wir oder
# [00:35:07,320 --> 00:35:12,590]  schreiben wir als kleinen Sigma. Das ist das leere Wort. So und dann kann man
# [00:35:12,590 --> 00:35:17,150]  natürlich für ein endliches Alphabet die Menge aller Wörter über diesem
# [00:35:17,150 --> 00:35:23,110]  Alphabet bilden. Einfach alle möglichen Folgen von Zeichenketten und Zeichen aus
# [00:35:23,110 --> 00:35:27,950]  dem Alphabet. Da gehört das leere Wort dazu. Das ist die Zeichenkette über dem
# [00:35:27,950 --> 00:35:32,030]  Alphabet, die die Länge 0 hat. Da gehören natürlich die Symbole aus dem
# [00:35:32,030 --> 00:35:37,870]  Alphabet dazu, also bei Sigma gleich 01, das Wort 0, das Wort 1, aber eben auch
# [00:35:37,870 --> 00:35:41,230]  längere Worte, die sie bilden können. Und das kann natürlich hier immer so
# [00:35:41,230 --> 00:35:47,580]  weitergehen. Das heißt also, das werden dann unendlich viele Wörter plötzlich.
# [00:35:47,580 --> 00:35:52,060]  Also das Alphabet ist endlich, aber wenn sie die Menge aller Wörter über dem
# [00:35:52,060 --> 00:35:58,140]  Alphabet bilden, dann bekommen sie eine unendliche Menge und die wird zum
# [00:35:58,140 --> 00:36:05,430]  Alphabet Sigma als Sigma-Stern bezeichnet. So, jetzt kann man natürlich
# [00:36:05,430 --> 00:36:10,670]  auch nach der Länge sozusagen Menge aller Wörter über Sigma einer bestimmten
# [00:36:10,670 --> 00:36:16,270]  Länge sozusagen Mengen bilden, Menge von Wörtern bilden. Also wenn man sagt
# [00:36:16,270 --> 00:36:21,590]  Menge aller Wörter der Länge N über dem Alphabet Sigma, dann bezeichnet man
# [00:36:21,590 --> 00:36:31,470]  diese Menge mit Sigma hoch N. Also Sigma hoch 0, das ist genau die Menge, die nur
# [00:36:31,470 --> 00:36:37,470]  das leere Wort enthält. Also es sind alle Wörter über Sigma der Länge 0, das
# [00:36:37,470 --> 00:36:43,630]  leere Wort. Sigma hoch 1, alle Wörter über Sigma der Länge 1, das sind zwei Wörter,
# [00:36:43,630 --> 00:36:49,170]  das Wort 0 und das Wort 1. Also die beiden Symbole haben wir in Sigma.
# [00:36:49,170 --> 00:36:55,610]  Entsprechend ist Sigma oben 1 die Menge 01. Menge aller Wörter der Länge 2, das
# [00:36:55,610 --> 00:37:00,290]  ist noch überschaubar. Alles, was sie über 01 bilden können an Zeichenfolgen der
# [00:37:00,290 --> 00:37:07,010]  Länge 2, das 00, 01, 1011. Das sind die vier und das können sie natürlich jetzt
# [00:37:07,010 --> 00:37:11,410]  immer so weiter treiben. Sigma hoch 17 und so. Das wäre natürlich sehr schnell sehr
# [00:37:11,410 --> 00:37:17,790]  viel mehr Wörter. Was man hier macht, ist also, dass man Zeichen aneinander hängt.
# [00:37:17,790 --> 00:37:22,510]  Und so wie man Zeichen aneinander hängt, kann man natürlich auch Folgen von Zeichen
# [00:37:22,510 --> 00:37:26,390]  aneinander hängen, also Wörter aneinander hängen. Und das ist der Begriff der
# [00:37:26,390 --> 00:37:31,870]  Konkatenation. Wenn Sie zwei beliebige Wörter W1 und W2 betrachten, dann können Sie
# [00:37:31,870 --> 00:37:37,940]  die Konkatenieren. Wir schreiben dann, wenn wir W1 und W2 in der Reihenfolge
# [00:37:37,940 --> 00:37:44,340]  konkatenieren, W1 pünktchen W2 oder W1 mal W2. Das schreiben wir aber abgekürzt
# [00:37:44,340 --> 00:37:49,740]  meistens ohne dieses Symbol in der Mitte, also W1 W2. Das ist einfach das Wort W1
# [00:37:49,740 --> 00:37:57,780]  und W2 dran gehängt. Also wenn W1 001 ist und W2 110, dann ist W1
# [00:37:57,780 --> 00:38:07,660]  konkateniert W2 001 110. Also Sie können aus Wörtern weitere Wörter bilden durch
# [00:38:07,660 --> 00:38:13,580]  Konkatenation. Sie können natürlich ein Wort W auch K fach mit sich selbst
# [00:38:13,580 --> 00:38:22,000]  konkatenieren. W, konkateniert W, konkateniert W und so weiter, K mal, so was
# [00:38:22,000 --> 00:38:29,570]  nennt man dann, bezeichnet man mit W hoch K. Also wenn unser Wort 110 ist, dann können
# [00:38:29,570 --> 00:38:34,210]  Sie das auch Null mal mit sich selbst konkatenieren. Das ist W hoch Null. Das ist
# [00:38:34,210 --> 00:38:39,340]  dann natürlich wieder das leere Wort. Oder eben einmal mit sich selbst, also nur
# [00:38:39,340 --> 00:38:46,400]  einmal hinschreiben W um 1, das ist das Wort selber. Oder eben einmal mit sich
# [00:38:46,400 --> 00:38:56,360]  selbst konkatenieren, also W, konkateniert W, W um 2, das 110 110 oder
# [00:38:56,480 --> 00:39:05,770]  3 mal und so weiter. So, das ist so das, was man mit Wörtern anstellen kann. Und
# [00:39:05,770 --> 00:39:15,560]  jetzt kann man Mengen von Wörtern als Sprachen auffassen. Und wir sagen ganz
# [00:39:15,560 --> 00:39:23,020]  einfach, so eine Menge L ist eine formale Sprache über einem Alphabet Sigma, wenn
# [00:39:23,020 --> 00:39:29,860]  dieses L einfach eine Teilmenge von Sigma Stern ist, also Teilmenge der Menge aller
# [00:39:29,860 --> 00:39:36,120]  möglichen Wörter, die man über Sigma bilden kann. Also irgendeine Teilmenge aus
# [00:39:36,120 --> 00:39:43,810]  Sigma Stern nennen wir formale Sprache. Beispiel. Klar, man kann das jetzt irgendwie
# [00:39:43,810 --> 00:39:48,940]  hinschreiben, eine bestimmte formale Sprache, indem man einfach die Wörter aufzählt.
# [00:39:48,940 --> 00:39:52,780]  Sie haben sehr oft natürlich formale Sprachen, die unendlich sind, die also
# [00:39:52,780 --> 00:39:58,730]  einfach hinzuschreiben, indem sie Wörter aufzählen. Das führt zu nichts. Sie
# [00:39:58,730 --> 00:40:03,070]  werden die also irgendwie beschreiben wollen. Und jetzt kann man vielleicht so
# [00:40:03,070 --> 00:40:07,350]  entsprechend der Anschauung beschreiben, dass man sagt, naja gut, also ich kann hier
# [00:40:07,350 --> 00:40:12,590]  Wörter über 01 bilden. Jetzt will ich als formale Sprache gerade die Wörter über 01,
# [00:40:12,590 --> 00:40:21,940]  die als vorletzte Symbol eine Null haben. Sprache als Strich aller Wörter, deren
# [00:40:21,940 --> 00:40:27,740]  vorletztes Zeichen Null ist. Das kann man natürlich beschreiben. Das sind Wörter,
# [00:40:27,740 --> 00:40:32,980]  die sehen so aus. Erst kommt irgendein Wort W, kann beliebig lang sein, kann beliebig
# [00:40:32,980 --> 00:40:40,120]  ein beliebiges Wort aus Sigma Stern sein. Also beliebige Folge von Nullen und Einsen. Und dann
# [00:40:40,120 --> 00:40:45,640]  kommt das vorletzte Symbol, das soll Null sein, und dann das letzte Symbol. Das darf Null oder
# [00:40:45,640 --> 00:40:50,680]  Eins sein. Das heißt also die Sprache aller Wörter, deren vorletztes Zeichen Null ist,
# [00:40:50,680 --> 00:40:58,740]  natürlich Wörter über Sigma, Sigma gleich 01. Das ist gerade die Menge aller Wörter,
# [00:40:58,740 --> 00:41:07,250]  die so aussehen. W, Null, Z. W ist ein Wort aus Sigma Stern, Z ist ein Symbol aus Sigma.
# [00:41:07,250 --> 00:41:16,360]  Okay, so das Produkt, jetzt kann man natürlich aus solchen Sprachen ein Produkt bilden. Das
# [00:41:16,360 --> 00:41:22,000]  Produkt von zwei Sprachen, L1 und L2, das definieren wir, na gut, das ist die Sprache,
# [00:41:22,000 --> 00:41:29,000]  die rauskommt, wenn man ein beliebiges Wort aus L1 konkateniert mit einem beliebigen Wort aus L2.
# [00:41:29,000 --> 00:41:40,270]  Also L1, Produkt L1 mal L2, der Sprachen L1 und L2, ist definiert als die Menge der Wörter W1
# ...
# [01:10:06,180 --> 01:10:11,140]  Und damit werden wir ganz oft zu tun haben, im Zusammenhang mit endlichen Automaten, aber auch
# [01:10:11,140 --> 01:10:18,100]  mit Tonmaschinen. Dann ist die grundlegende Frage, die man sich natürlich als allererste stellt,
# [01:10:18,100 --> 01:10:28,850]  was kann so ein endlicher Automat, so ein ganz einfach aufgebautes Modell einer Berechnungsmaschine.
# [01:10:28,850 --> 01:10:41,450]  Na gut, was gibt man dem Automat als Eingabe, irgendeine Zeichenkette aus dem Alphabet und was
# [01:10:41,450 --> 01:10:46,410]  kann der Automat damit machen? Na ja gut, in Abhängigkeit, wie die Zeichenkette aussieht,
# [01:10:46,410 --> 01:10:52,890]  kann er entsprechend seiner Übergangsfunktion vom Startzustand aus weiter in weitere Zustände gehen,
# [01:10:52,890 --> 01:11:00,120]  jeweils durchlesen ein Symbol und dann nach Abarbeitung des Wortes in irgendeinem Zustand
# [01:11:00,120 --> 01:11:08,100]  landen. Wenn der Zustand, in dem man landet bei Abarbeitung, so eine Eingabe einer aus dieser
# [01:11:08,100 --> 01:11:15,780]  Zustandsmenge F, Menge der ausgezeichneten Endzustände ist, dann sagen wir, der endliche
# [01:11:15,780 --> 01:11:21,740]  Automat akzeptiert das Wort. Also wir sagen, ein endlicher Automat erkennt oder akzeptiert eine
# [01:11:21,740 --> 01:11:29,270]  Sprache, das heißt eine Menge von Wörtern über dem Alphabet, das der Automat kennt, wenn er nach
# [01:11:29,270 --> 01:11:35,710]  Abarbeitung eines jeden Wortes aus der Sprache und genau nach Abarbeitung dieser Worte in einem
# [01:11:35,710 --> 01:11:43,190]  akzeptierenden, also in so einem Endzustand F landet. Also wenn er genau bei Abarbeitung von
# [01:11:43,190 --> 01:11:54,820]  Wörtern aus L in einem Zustand aus F landet, sagen wir, er akzeptiert die Sprache L. Und wir
# [01:11:54,820 --> 01:11:59,700]  nennen dann so eine Sprache, zu der wir einen Automaten angeben können, einen endlichen Automaten,
# [01:11:59,700 --> 01:12:08,030]  der genau diese Sprache akzeptiert, auch endliche Automatensprache. Das heißt also diese Frage,
# [01:12:08,030 --> 01:12:14,070]  was kann ein endlicher Automat? Die könnte man auch umformulieren in, ja, welches sind denn die
# [01:12:14,070 --> 01:12:20,630]  formalen Sprachen, die endliche Automatensprachen sind? Sind das alle formale Sprachen oder nur eine
# [01:12:20,630 --> 01:12:28,390]  ausgewählte Menge von formalen Sprachen? So, Beispiel für einen einfachen, endlichen Automat.
# [01:12:28,390 --> 01:12:33,710]  Ignorieren Sie jetzt mal, was hier in den Zuständen drin steht. Den Automaten werden wir später halt
# [01:12:33,710 --> 01:12:38,750]  wieder treffen und da wird das eine Rolle spielen, was hier drin steht. Also der hat einfach vier
# [01:12:38,750 --> 01:12:44,990]  Zustände. Den hier, das ist der Startzustand, dann einen weiteren Zustand, noch einen Zustand,
# [01:12:44,990 --> 01:12:50,750]  noch einen Zustand und die beiden hier mit zwei Kringeln drum, was sollen die ausgezeichneten
# [01:12:50,750 --> 01:12:59,150]  Endzustände sein? Also die Menge Q besteht aus den vier Zuständen und die Menge F besteht aus den
# [01:12:59,150 --> 01:13:05,110]  beiden Zuständen und S, der Anfangszustand, oft nennen wir den auch Q0, sollte ich vielleicht
# [01:13:05,110 --> 01:13:12,030]  dazu sagen, ist der hier. So und die Übergangsfunktion ist grafisch dargestellt über diese Pfeile,
# [01:13:12,030 --> 01:13:21,740]  nämlich wenn wir in S, in dem Zustand S sind, im Anfangszustand und das Symbol 0 lesen, dann führt
# [01:13:21,740 --> 01:13:27,580]  uns die Zustandsübergangsfunktion in diesen Zustand. Oder wenn wir in dem Anfangszustand das
# [01:13:27,580 --> 01:13:33,340]  Symbol 1 lesen, dann führt uns die Zustandsübergangsfunktion in den Zustand selbst wieder
# [01:13:33,340 --> 01:13:45,540]  und so weiter. Was ist das für ein Automat? Welche Sprache akzeptiert der? Na ja gut,
# [01:13:45,540 --> 01:13:52,020]  davon müsste man analysieren, welche Worte, genau welche Worte führen hierhin oder hierhin.
# [01:13:52,020 --> 01:13:58,560]  Also man guckt zum Beispiel, wie kommt man hier hin? Ja, da kommt man hin, wenn man eine Null
# [01:13:58,560 --> 01:14:06,230]  liest und dann eine Null. Oder ein paar Einsen liest, dann eine Null und dann eine Null liest.
# [01:14:06,230 --> 01:14:12,660]  Oder ein paar Einsen, eine Null liest, eine Null liest und noch mal ein paar Nullen liest. Und
# [01:14:12,660 --> 01:14:19,860]  wie kommt man hier hin? Indem man eine Null liest und dann eine Eins liest. Oder ein paar Einsen
# [01:14:19,860 --> 01:14:26,060]  liest, dann eine Null und dann eine Eins liest. Oder ein paar Einsen liest, eine Null, eine Eins,
# [01:14:26,060 --> 01:14:34,020]  eine Null und wieder eine Eins, oder aber indem man eine Null liest, eine Null und dann eine Eins.
# [01:14:34,020 --> 01:14:39,860]  Also wenn man sich das alles so anguckt, dann vermutet man, das ist der endliche Automat,
# [01:14:39,860 --> 01:14:47,600]  der genau die Sprache aller Wörter, deren vorletztes Symbol eine Null ist, akzeptiert.
# [01:14:47,600 --> 01:14:55,040]  Gut, das war jetzt so durch Händewedeln der Beweis, dass das tatsächlich dieser Automat ist,
# [01:14:55,040 --> 01:15:03,780]  und systematisch aufbauen will, sozusagen wie die Sprache aussieht, die von diesem Automaten
# [01:15:03,780 --> 01:15:10,260]  akzeptiert wird, dann braucht man da irgendwie ein Werkzeug für. Und das werden wir auch kennenlernen,
# [01:15:10,260 --> 01:15:17,490]  also sozusagen eine systematische Art für so einen endlichen Automat, die entsprechende Sprache
# [01:15:17,490 --> 01:15:23,980]  hinzuschreiben, die von dem Automaten akzeptiert wird. Also hier ist es, wie gesagt, die Sprache
# [01:15:23,980 --> 01:15:28,540]  aller Wörter, deren vorletztes Symbol Null ist, also diese hier, die wir auch schon als reguläre
# [01:15:28,540 --> 01:15:37,880]  Sprache identifiziert haben. Zum Abschluss heute noch Wiederholung, was kontextfreie Grammatiken sind.
# [01:15:37,880 --> 01:15:50,180]  Ja, so eine Grammatik, die besteht aus einem endlichen Alphabet Sigma, nennen wir auch diese
# [01:15:50,180 --> 01:16:01,210]  Menge Terminalalphabet. Es gibt nämlich noch eine weitere Menge von Symbolen, V, Symbole der
# [01:16:01,210 --> 01:16:15,950]  nicht Terminale. Diese Menge hat leeren Schnitt mit der Menge der Terminalsymbole. Dann gibt es ein
# [01:16:15,950 --> 01:16:21,670]  Startsymbol und dann gibt es eine Menge von Regeln. Das Startsymbol ist so nicht Terminal oder auch
# [01:16:21,670 --> 01:16:29,240]  Variable genannt. Und die Frage ist jetzt, was ist das da hinten? So wie wir beim endlichen Automaten
# [01:16:29,240 --> 01:16:33,720]  so eine Übergangsfunktion haben, haben wir hier eine Menge von Regeln. Und die Frage ist, wie sehen
# [01:16:33,720 --> 01:16:40,260]  die aus? Also so eine Ableitungsregel, die kann man beschreiben durch so ein Truppel links-rechts oder
# [01:16:40,260 --> 01:16:51,220]  LR, wobei das L eine Variable ist und das R irgendein Wort sein kann, ein gemischtes Wort aus Terminal
# [01:16:51,220 --> 01:16:57,100]  und nicht Terminalsymbolen. Also ein Wort aus der Sprache, die man bekommt, wenn man sigma-vereinigt
# [01:16:57,100 --> 01:17:05,640]  Menge der Variablen hernimmt und da den klinischen Abschluss bildet. Also das hier ist das Spannende,
# [01:17:05,640 --> 01:17:11,560]  diese Ableitungsregeln, die schreiben wir auch als in der Form, also dieses Truppel L, R schreiben wir
# [01:17:11,560 --> 01:17:17,410]  auch in der Form L-Pfeil R. Und das sind also Produktionsregeln und die gucken wir uns jetzt mal
# [01:17:17,410 --> 01:17:27,660]  genauer an. Da kann man aus Worten neue Worte mit bilden. Wenn man ein Wort hat, wo irgendwo L
# [01:17:27,660 --> 01:17:35,060]  vorkommt, also so ein W, das irgendwo das Zeichen L, die Variable L enthält, dann kann man an der
# [01:17:35,060 --> 01:17:44,680]  Stelle L ersetzen durch R, das Wort R, wenn ich die Produktionsregel LR habe. Und kriegt dann ein
# [01:17:44,680 --> 01:17:54,490]  neues Wort. Dann schreibt man auch, wenn man das macht, durch Ersetzen von L in dem Wort W durch R
# [01:17:54,490 --> 01:18:02,930]  kriege ich ein neues Wort Z, dann schreibt man auch, auch W habe ich abgeleitet zu Z. Und wenn
# [01:18:02,930 --> 01:18:11,290]  ich über Anwendung von mehreren Produktionsregeln aus W Z bekommen kann, dann schreibe ich auch W-Pfeil
# [01:18:11,290 --> 01:18:20,590]  Z mit zum Sternchen drüber. So, jetzt wofür ist so eine Grammatik gut? Die ist gut, um wieder
# [01:18:20,590 --> 01:18:27,250]  Sprachen zu beschreiben oder eine Sprache zu beschreiben, nämlich die Sprache, die all die Wörter
# [01:18:27,250 --> 01:18:35,890]  enthält, die ich durch beliebige Anwendung, Anwenden von Ableitungsregeln der Grammatik aus dem
# [01:18:35,890 --> 01:18:42,530]  Stachsymbol generieren kann. Also wenn ich so eine Grammatik G habe, bestehend aus Sigma, Variablen
# [01:18:42,530 --> 01:18:50,890]  Menge V, Stachsymbol S und R, Menge von Ableitungsregeln, dann ist L von G, also die Sprache zu dieser
# [01:18:50,890 --> 01:18:58,660]  Grammatik, gerade die Menge all der Wörter Z über dem Alphabet Sigma, also aus Sigma Stern, die ich
# [01:18:58,660 --> 01:19:06,660]  bekomme, wenn ich auf S, angefangen bei S, eine beliebige Folge von Ableitungsregeln aus R anwende.
# [01:19:06,660 --> 01:19:14,090]  Und das gucken wir uns mal am Beispiel an. Also meinetwegen, wir hätten folgende Grammatik. Das
# [01:19:14,090 --> 01:19:24,340]  Alphabet ist 0,1, wie wir es jetzt schon die ganze Zeit angeguckt haben. Das Stachsymbol ist S und die
# [01:19:24,340 --> 01:19:29,980]  Variablenmenge enthält auch nichts weiter als das Stachsymbol, also V Variablenmenge oder
# [01:19:29,980 --> 01:19:37,060]  Terminalalphabet, nicht Terminalalphabet ist Menge mit S und die Ableitungsregeln sind folgendermaßen
# [01:19:37,060 --> 01:19:45,940]  aus. Ich kann das Stachsymbol ersetzen durch 0,1 oder ich kann das Stachsymbol, das Stachsymbol
# [01:19:45,940 --> 01:19:54,460]  ersetzen durch 0 Stachsymbol 1. Also ich habe nur zwei mögliche Regeln und bei beiden Regeln steht
# [01:19:54,460 --> 01:19:59,980]  links das Stachsymbol, das ist auch die einzige Variable, die ich zur Verfügung habe und rechts
# [01:19:59,980 --> 01:20:07,580]  jeweils ein Wort aus Sigma vereinigt V in Klammer Sternchen und es gibt da nur zwei Möglichkeiten,
# [01:20:07,580 --> 01:20:16,900]  nämlich dass rechts einfach das Wort 0,1 steht oder rechts 0, S, 1 steht. Das hier, also diese
# [01:20:16,900 --> 01:20:22,260]  Menge von Regeln, die schreibe ich auch oft verkürzt einfach als, wenn da links dasselbe
# [01:20:22,260 --> 01:20:29,980]  Symbol steht. Ich kann dieses Symbol ableiten, entweder zu 0,1 oder zu 0, S, 1, also indem ich
# [01:20:29,980 --> 01:20:36,100]  einfach hier rechts das kompakte schreibe. Welche Wörter kann man auf die Art und Weise bekommen,
# [01:20:36,100 --> 01:20:45,320]  ist die Frage. Was kann ich machen? Ich kann S ersetzen durch 0,1 oder durch 0, S, 1. Was kann
# [01:20:45,320 --> 01:20:51,810]  ich durch weitere Anwendungen von Produktionsregeln bekommen? Entweder ich mache hier gar nichts mehr,
# [01:20:52,570 --> 01:20:58,970]  ende damit oder ich ersetze hier dieses S und da gibt es wieder zwei Möglichkeiten. Ich ersetze
# [01:20:58,970 --> 01:21:06,530]  entweder S durch 0, 1, dann bekomme ich 0, 0, 1, 1 oder ich ersetze S durch 0, S, 1, dann bekomme
# [01:21:06,530 --> 01:21:13,780]  ich 0, 0, S, 1, 1. Wenn ich da weitere Regeln anwende, behalte ich erstmal die Worte, die ich
# [01:21:13,780 --> 01:21:22,780]  schon habe und aus dem hinteren bekomme ich entweder 0, 0, 0, 1, 1, 1 oder 0, 0, 0, S, 1, 1, 1 und so
# [01:21:22,780 --> 01:21:30,340]  weiter. Das Schema ist ziemlich schnell klar. Das Ganze endet jeweils bei Wörtern wie hier auch
# [01:21:30,340 --> 01:21:35,940]  schon, die nur noch Symbole aus Sigma enthalten und diese Wörter sehen natürlich so aus, das ist
# [01:21:35,940 --> 01:21:40,260]  eine Folge von Nullen, gefolgt von einer Folge von Einsen und sind immer genauso viele Einsen wie
# [01:21:40,260 --> 01:21:49,170]  Nullen. Das heißt also, diese Grammatik erzeugt gerade die Sprache 0 hoch N, 1 hoch N, N eine
# [01:21:49,170 --> 01:21:59,840]  natürliche Zahl. So und jetzt die Sprache, die wir jetzt schon mehrmals hatten, die Sprache der
# [01:21:59,840 --> 01:22:04,880]  Wörter, deren vorletztes Symbol 0 ist und die Wörter sollen auch außer Nullen und Einsen nichts
# [01:22:04,880 --> 01:22:15,340]  enthalten. Kann ich die über eine Grammatik beschreiben? Okay, dann schlage ich mal Folgende
# [01:22:15,340 --> 01:22:24,180]  vor, also Sigma ist 01. Als Variablenmenge nehme ich die Menge, die S, also Stachsymbol, eine weitere
# [01:22:24,180 --> 01:22:30,100]  Variable A und eine weitere Variable B enthält und folgende Regeln schlage ich Ihnen vor. Aus S kann
# [01:22:30,100 --> 01:22:40,260]  ich ableiten A0 oder A1, aus A kann ich ableiten B0 und aus B kann ich ableiten das Leerwort oder B0
# [01:22:40,260 --> 01:22:49,660]  oder B1. Und sich das mal an und die Zuständigkeit dieser Regeln, wofür sind die Regeln zuständig?
# [01:22:49,660 --> 01:23:00,260]  Die ersten beiden Regeln sind dafür zuständig, das hintere Symbol zu generieren. Also bei einem
# [01:23:00,260 --> 01:23:07,580]  Wort, das als vorletztes Symbol 0 enthält, habe ich hinten eine 0 oder eine 1 und davor ist eine 0
# [01:23:07,580 --> 01:23:14,420]  und davor ist irgendetwas Beliebiges. Und die beiden Regeln S nach A0 und S nach A1, die setzen
# [01:23:14,420 --> 01:23:21,660]  gerade dieses letzte Symbol, da sitzt das. Davor muss jetzt noch was produziert werden und dass
# [01:23:21,660 --> 01:23:29,860]  das vorletzte Symbol eine 0 ist, worauf ich achten muss, dafür sind die Regeln zuständig,
# [01:23:29,860 --> 01:23:42,160]  die aus A ableiten. Nämlich aus A kann ich nur eine Sache ableiten, B0. Und wofür ist jetzt,
# [01:23:42,160 --> 01:23:47,000]  oder wie kriege ich jetzt, dass vor dieser 0, dem vorletzten Symbol, dass eine 0 ist,
# [01:23:47,000 --> 01:23:52,440]  was Beliebiges stehen kann, na dafür sind die Regeln zuständig, die aus B ableiten. Da kann
# [01:23:52,440 --> 01:24:00,340]  gar nichts stehen da vorne, also das Wort sieht nur so aus 0 0 oder 0 1 oder irgendwas. Und das
# [01:24:00,340 --> 01:24:13,680]  wird halt durch 0 1 0 1 davor schreiben generiert. Und dafür kann nach B0 nach B1 abgeleitelt werden,
# [01:24:13,680 --> 01:24:17,760]  das kann ich auch in beliebiger Reihenfolge solche Regeln jetzt noch anwenden. Und wenn dann mal
# [01:24:17,760 --> 01:24:22,720]  irgendwann Schluss ist, ich sage so jetzt das Wort fertig generiert, dann ersetze ich B einfach
# [01:24:22,720 --> 01:24:30,580]  durch Epsilon. Das heißt also, eine Ableitung irgendeines Wortes aus der Sprache, die hierfür
# [01:24:30,580 --> 01:24:38,380]  hier durch generiert wird, sieht so aus. Ich fange bei S an und da gibt es nur zwei mögliche Regeln,
# [01:24:38,380 --> 01:24:48,590]  S nach A0 oder S nach A1. Und dann mache ich weiter. Weitermachen heißt, eine Regel für A wird
# [01:24:48,590 --> 01:24:56,220]  abgeleitet anwenden. Dafür habe ich nur eine. A wird abgeleitet nach B0. Das heißt also im ersten
# [01:24:56,220 --> 01:25:02,460]  Fall bekomme ich B0 0, im zweiten Fall, also wenn ich von S aus erstmal A1 generiert habe, bekomme
# [01:25:02,460 --> 01:25:11,340]  ich B0 1. So und dann alles, was ich kriegen kann an Worten, wo keine Variablen mehr drin sind,
# [01:25:11,340 --> 01:25:19,540]  aus B0 0 und B0 1 durch Anwenden dieser Regeln. Ja gut, das ist alles, was hier vorne beliebiges
# [01:25:19,540 --> 01:25:36,040]  noch davor schreibt. Beliebiges bestehend aus 0 und 1. Okay, so das war die Wiederholung und
# [01:25:36,040 --> 01:25:42,480]  damit bin ich auch am Ende. Grammatiken, wie die kontextfreien Grammatiken werden wir später in
# [01:25:42,480 --> 01:25:46,840]  der Vorlesung betrachten und da werden wir eben auch noch mehr als diese kontextfreien Grammatiken
# [01:25:46,840 --> 01:25:48,560]  kennenlernen. So, das wäre es für heute.
# **Output file created: /content/drive/My Drive/Colab Notebooks/Faster Whisper/gg.txt**
